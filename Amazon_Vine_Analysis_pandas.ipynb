# %%
import pandas as pd

# %%
df = pd.read_csv('vine_table.csv')

# %%
display(df)
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0         RED72VWWCOS7S          1.0            2.0          8.0    N
# 1         RZHWQ208LTEPV          5.0            0.0          0.0    N
# 2        R37LBC3XAVLYOO          5.0            4.0          5.0    N
# 3        R3L7XJMA0MVJWC          5.0            0.0          0.0    N
# 4        R2I2GHSI7T1UBN          1.0            5.0          6.0    N
# ...                 ...          ...            ...          ...  ...
# 2557283  R3MV8JFJJJ3WU0          2.0           12.0         12.0    N
# 2557284   RGL89WE5DFU75          5.0           19.0         24.0    N
# 2557285  R203ZDOKV987E5          3.0          231.0        236.0    N
# 2557286   R8GD7D9HK6S2W          5.0           17.0         29.0    N
# 2557287  R2QCF5NWYPK06U          5.0           86.0        106.0    N
#
#         verified_purchase
# 0                       Y
# 1                       Y
# 2                       Y
# ...

# %%
df.dtypes
# Out:
# review_id             object
# star_rating          float64
# helpful_votes        float64
# total_votes          float64
# vine                  object
# verified_purchase     object
# dtype: object

# %%
df_20 = df[df['total_votes'] >= 20.0]

# %%
display(df_20)
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 159       RQQ3KVTU5TJ4I          5.0           24.0         29.0    N
# 213      R3FELXWV9T5CWE          2.0           22.0         24.0    N
# 225       ROBYK6EZYK398          5.0           29.0         30.0    N
# 252      R2RKCSAG6GBA4A          1.0            8.0         28.0    N
# 311      R2YVBBR6NXIA4V          5.0           25.0         28.0    N
# ...                 ...          ...            ...          ...  ...
# 2557282  R19OAQWX9CYMOQ          3.0           45.0         52.0    N
# 2557284   RGL89WE5DFU75          5.0           19.0         24.0    N
# 2557285  R203ZDOKV987E5          3.0          231.0        236.0    N
# 2557286   R8GD7D9HK6S2W          5.0           17.0         29.0    N
# 2557287  R2QCF5NWYPK06U          5.0           86.0        106.0    N
#
#         verified_purchase
# 159                     Y
# 213                     Y
# 225                     Y
# ...

# %%
df_20['useful'] = (df_20['helpful_votes'] / df_20['total_votes'] )
# Out:
# C:\Users\Will\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_useful = df_20[df_20['useful'] >= 0.5]

# %%
display(df_useful)
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 159       RQQ3KVTU5TJ4I          5.0           24.0         29.0    N
# 213      R3FELXWV9T5CWE          2.0           22.0         24.0    N
# 225       ROBYK6EZYK398          5.0           29.0         30.0    N
# 311      R2YVBBR6NXIA4V          5.0           25.0         28.0    N
# 558      R2AVTBDIVG2AW4          5.0           26.0         26.0    N
# ...                 ...          ...            ...          ...  ...
# 2557282  R19OAQWX9CYMOQ          3.0           45.0         52.0    N
# 2557284   RGL89WE5DFU75          5.0           19.0         24.0    N
# 2557285  R203ZDOKV987E5          3.0          231.0        236.0    N
# 2557286   R8GD7D9HK6S2W          5.0           17.0         29.0    N
# 2557287  R2QCF5NWYPK06U          5.0           86.0        106.0    N
#
#         verified_purchase    useful
# 159                     Y  0.827586
# 213                     Y  0.916667
# ...

# %%
df_Y = df_useful[df_useful['vine'] == 'Y']

# %%
display(df_Y)
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 37363    R28DXTC3JQ9IY1          4.0           24.0         26.0    Y
# 58520    R3AFZKLQXATHBU          5.0           44.0         49.0    Y
# 83985    R2RUUF2JPJPC0E          4.0           20.0         22.0    Y
# 90459     RFZ2WUH4248AB          2.0           26.0         27.0    Y
# 95122    R1Q4LVHIFOWYFR          5.0           23.0         28.0    Y
# ...                 ...          ...            ...          ...  ...
# 2493457  R3VJ31ZXGGEIA7          3.0           26.0         40.0    Y
# 2496815  R3G3DHILRCTHU7          4.0           28.0         28.0    Y
# 2498001  R3KEI56N0J7WVA          5.0           63.0         64.0    Y
# 2498022  R27NCPPLBK9MJM          5.0           31.0         33.0    Y
# 2498072  R29XHJ9MWZM9TK          5.0          305.0        322.0    Y
#
#         verified_purchase    useful
# 37363                   N  0.923077
# 58520                   N  0.897959
# ...

# %%
df_N = df_useful[df_useful['vine'] == 'N']

# %%
df_5 = df_useful[df_useful['star_rating'] == 5.0]
display(df_5)
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 159       RQQ3KVTU5TJ4I          5.0           24.0         29.0    N
# 225       ROBYK6EZYK398          5.0           29.0         30.0    N
# 311      R2YVBBR6NXIA4V          5.0           25.0         28.0    N
# 558      R2AVTBDIVG2AW4          5.0           26.0         26.0    N
# 1368       RLNULBKRWNNR          5.0           42.0         43.0    N
# ...                 ...          ...            ...          ...  ...
# 2557276  R22RSZPUWBOOCA          5.0           21.0         31.0    N
# 2557278  R22GEU6PHDLLLF          5.0           27.0         30.0    N
# 2557284   RGL89WE5DFU75          5.0           19.0         24.0    N
# 2557286   R8GD7D9HK6S2W          5.0           17.0         29.0    N
# 2557287  R2QCF5NWYPK06U          5.0           86.0        106.0    N
#
#         verified_purchase    useful
# 159                     Y  0.827586
# 225                     Y  0.966667
# ...

# %%
total_reviews = len(df_useful)
total_5star_reviews = len(df_5)

# %%
star5_paid = (len(df_5[df_5['verified_purchase'] == 'Y'])) / (total_5star_reviews)
print(star5_paid)

star5_unpaid = (len(df_5[df_5['verified_purchase'] == 'N'])) / (total_5star_reviews)
print(star5_unpaid)
# Out:
# 0.703206346582927
# 0.296793653417073
